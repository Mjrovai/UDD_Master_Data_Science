# %% [markdown]
# #  San Miguel Portal Inmobiliario Web Scraping
# Por Marcelo Rovai<br>
# 17 Deciembre 2018

# %% [markdown]
# https://www.portalinmobiliario.com/

# %%
from time import sleep
import pandas as pd
from bs4 import BeautifulSoup
import requests
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
def sumario_estat(df, title):
    n = df.count()
    mu = int(df.mean())
    md = int(df.median())
    mn = int(df.min())
    mx = int(df.max())
    rg = int(np.ptp(df))
     
    print ("\n * Resumen: "+title+ "*\n")
    print("Propriedades:  ", n)
    print("Precio Medio:  ${0:,}".format(mu))
    print("Precio Cntr :  ${0:,}".format(md))
    print("Precio min. :  ${0:,}".format(mn))
    print("Precio max. :  ${0:,}".format(mx))
    print("Rango precios: ${0:,}".format(rg))

# %% [markdown]
# ## Arriendos: parametros

# %%
negocio = 'arriendo'  # venta o arriendo
tipo = 'departamento'  # departamento, casa, oficina, sitio, parcela, etc.
comuna = 'san-miguel'
region = 'metropolitana'
estado = 'usado'  # nuevo; usado; indiferente
dorm_min = '2'  # 0 ==> 6
dorm_max = '3'  # 0 ==> 6
bano_min = '1'  # 0 ==> 6
bano_max = '1'  # 0 ==> 6
moneda = 'pesos'  # pesos; UFs
precio_min = '100.000'
precio_max = '500.000'
sup_min = '40,00'
sup_max = '60,00'
num_max_paginas = 5

# %%
# executar la query para un numero de paginas

title = (negocio+' '+tipo+' '+comuna)
if estado == 'nuevo': 
    condicion ="1"
elif estado == 'usado':
     condicion ="2"
else: 
    condicion ="3"
    
if moneda == 'pesos': 
    uni_mon ="1"
else: 
    uni_mon ="2" 

# print("En caso response ==> [200], todo OK!")
# print (r)
print("")

print("_____________________________________________")
print(title)
print("")
print ("Estado      : {}".format(estado))
print ("Habitaciones: de {} hasta {}".format(dorm_min, dorm_max))
print ("Baños       : de {} hasta {}".format(bano_min, bano_max))
print("Superficie m2: de {} hasta {}".format(sup_min, sup_max))
print("Precios en {}: de {} hasta {}".format(moneda, precio_min, precio_max))
print("_____________________________________________\n")

depts = []
for i in range(num_max_paginas):
    URL = "https://www.portalinmobiliario.com/" + negocio + "/" + tipo + "/" + comuna + "-" + region + "?tp=2&op=1&ca=" + condicion + "&ts=1&dd=" + dorm_min + "&dh=" + dorm_max + "&bd=" + bano_min + "&bh=" + bano_max + "&or=&mn=" + uni_mon + "&sf=1&sp=1&pd=" + precio_min + "&ph=" + precio_max + "&sd=" + sup_min + "&sh=" + sup_max+"&pg="+str(i+1)
    #print(URL)
    r = requests.get(URL)
    print(i, end="")
    sleep(10)
    res = BeautifulSoup(r.text, 'html5lib')   
    deptos = res.find_all('div', {'class':'product-item-data'})
    for d in deptos:
        dept = []
        d1 = d.find('h4').text
        dept.append(d1)
        for p in d.find_all('p'):
            d2 = p.text
            dept.append(d2)
        depts.append(dept)
dep_df = pd.DataFrame(depts)  
del dep_df[1]
dep_df.columns = ['propriedad', 'codigo', 'tipo', 'valor', 'superficie']
dep_df['valor'] = dep_df.valor.str.split(expand=True)[2]
dep_df['valor'] = dep_df.valor.str.split(',', expand=True)[0]
dep_df.valor.replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
dep_df['valor'] = pd.to_numeric(dep_df['valor'])
dep_df['codigo'] = dep_df.codigo.str.split(expand=True)[1]
dep_df['superficie'] = dep_df.superficie.str.split(expand=True)[1]
dep_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bbc63594515c> in <module>
#       1 # executar la query para un numero de paginas
#       2
# ----> 3 title = (negocio+' '+tipo+' '+comuna)
#       4 if estado == 'nuevo':
#       5     condicion ="1"
#
# NameError: name 'negocio' is not defined

# %%
san_miguel_2D = dep_df[dep_df.tipo == '2D/1B']
sumario_estat(san_miguel_2D.valor, title)
san_miguel_2D
# Out:
#  * Resumen: arriendo departamento san-miguel*
#
# Propriedades:   46
# Precio Medio:  $358,392
# Precio Cntr :  $350,816
# Precio min. :  $295,001
# Precio max. :  $430,026
# Rango precios: $135,025
#                                            propriedad   codigo   tipo   valor  \
# 0                   María Auxiliadora 860, San Miguel  4447884  2D/1B  330439
# 1   Cuarta Avenida 1447 - Departamento 1447, San M...  4461575  2D/1B  350188
# 2                                          San Miguel  4484825  2D/1B  374999
# 3   Séptima Avenida 1234 - Departamento 75, San Mi...  4473692  2D/1B  380000
# 4                        EXCELENTE ESTADO, San Miguel  4473805  2D/1B  295001
# 5    Jose Miguel Carrera  / Av. Lo Ovalle, San Miguel  4256734  2D/1B  303370
# 6                     Cuarta avenida 1175, San Miguel  4264153  2D/1B  318253
# 7                    SAN NICOLÁS / CHILOÉ, San Miguel  4296371  2D/1B  320000
# 9                     Quinta Avenida 1475, San Miguel  4444951  2D/1B  325001
# 10  Metro Ciudad del Niño - Metro Ciudad del, San ...  4475764  2D/1B  329000
# 13        MARÍA AUXILIADORA // SANTA ROSA, San Miguel  4470731  2D/1B  330001
# 14                Avenida Salesianos 1400, San Miguel  4455899  2D/1B  335266
# 15                   Cuarta Avenida  1175, San Miguel  4431436  2D/1B  335760
# 17                   Séptima Avenida 1355, San Miguel  4468813  2D/1B  345000
# 18          Avda Salesianos / San Ignacio, San Miguel  4473241  2D/1B  350000
# 20                    Metro Departamental, San Miguel  4450915  2D/1B  350000
# 21  SALESIANOS 870 / A DOS CUADRAS DE GRAN AVENIDA...  4452748  2D/1B  350000
# 22                      Av Salesianos 870, San Miguel  4454973  2D/1B  350000
# 23                    Guard Riquelme 4861, San Miguel  4160001  2D/1B  350000
# 24  Guard Riquelme 4861 - Departamento piso15, San...  4165054  2D/1B  350000
# 26                  Álvarez de Toledo 845, San Miguel  4463861  2D/1B  350141
# 27  Se arrienda departamento 2 Dormitorios 1 Baño ...  4436674  2D/1B  350278
# 28                  Maria Auxiliadora 721, San Miguel  4448630  2D/1B  350466
# 29   Primera Avenida / SegundaTransversal, San Miguel  4439053  2D/1B  350607
# 30                    Guard Riquelme 4861, San Miguel  4431505  2D/1B  350794
# 31                       San Nicolás 1033, San Miguel  4430526  2D/1B  350838
# 32   SAN MIGUEL ALCALDE PEDRO ALARCON 868, San Miguel  4425416  2D/1B  350932
# 33  Avenida Salesianos 1350 - Departamento 46, San...  4370644  2D/1B  350932
# 34           Guardia Marina Riquelme 4861, San Miguel  4422039  2D/1B  350979
# 35  Guardiamarina Riquelme 4861 - Departamento 130...  4233421  2D/1B  352572
# 36  Metro Lo Vial - San Ignacio / La Marina, San M...  4389876  2D/1B  359574
# 37           Guardia Marina Riquelme 4861, San Miguel  4401212  2D/1B  360001
# 38         A pasos Metro Lo Vial / Chiloe, San Miguel  4454928  2D/1B  360288
# 39                    Guard Riquelme 4861, San Miguel  4216519  2D/1B  360814
# 42                             Milán 1437, San Miguel  4388596  2D/1B  376827
# 44           Guardia Marina Riquelme 4861, San Miguel  4422044  2D/1B  383068
# 45                    Guard Riquelme 4861, San Miguel  4177034  2D/1B  385237
# 46  Llano subercaseaux / Hospital Exequiel Gonzale...  4302326  2D/1B  391409
# 47  Guardiamarina Riquelme 4861 - Departamento 130...  4251807  2D/1B  392865
# 48                    Guard Riquelme 4861, San Miguel  4431506  2D/1B  392887
# 49   Octava Avenida/Metro Ciudad del Niño, San Miguel  4297440  2D/1B  392945
# 50                    OCTAVA AVENIDA 1358, San Miguel  4481258  2D/1B  399999
# 51  Fernando lazcano  1450 - Departamento 10, San ...  4260408  2D/1B  403329
# 52                  Álvarez de Toledo 924, San Miguel  3614236  2D/1B  405631
# 53                 Ramón Barros Luco 4010, San Miguel  4454837  2D/1B  410328
# 54         Llano Subercaseaux, San Miguel, San Miguel  4463743  2D/1B  430026
#
#    superficie
# 0          50
# 1          55
# 2          50
# 3          57
# 4          49
# 5          50
# 6          45
# 7          43
# 9          40
# 10         45
# 13         47
# 14         40
# 15         48
# 17         47
# 18      43,80
# 20         40
# 21         48
# 22         48
# 23         48
# 24      40,30
# 26         42
# 27         45
# 28         40
# 29         56
# 30      47,50
# 31         45
# 32         45
# 33         45
# 34      40,30
# 35         48
# 36         45
# 37         50
# 38         56
# 39         43
# 42         48
# 44      47,50
# 45      43,53
# 46         55
# 47         47
# 48      47,50
# 49         52
# 50         50
# 51         49
# 52         55
# 53         48
# 54         53

# %%
san_miguel_3D = dep_df[dep_df.tipo == '3D/1B']
sumario_estat(san_miguel_3D.valor, title)
san_miguel_3D
# Out:
#  * Resumen: arriendo departamento san-miguel*
#
# Propriedades:   9
# Precio Medio:  $348,918
# Precio Cntr :  $350,000
# Precio min. :  $320,171
# Precio max. :  $380,000
# Rango precios: $59,829
#                                            propriedad   codigo   tipo   valor  \
# 8   AV SANTA ROSA - MARIA AUXILIADORA - PEDRO ALAR...  4387133  3D/1B  320171
# 11         Santa Rosa / Maria Auxiliadora, San Miguel  4483819  3D/1B  330001
# 12         Santa Rosa / Maria Auxiliadora, San Miguel  4483820  3D/1B  330001
# 16    Maria auxiliadora  / Av. Santa rosa, San Miguel  4445738  3D/1B  339999
# 19                  María Auxiliadora 721, San Miguel  4485368  3D/1B  350000
# 25           Maria Auxiliadora/Santa Rosa, San Miguel  4457009  3D/1B  350094
# 40  Avenida Centenario 1000 - Departamento 91, San...  4418894  3D/1B  369999
# 41  Guardia Marina Riquelme 4861 - Departamento 12...  4486080  3D/1B  369999
# 43                  María Auxiliadora 721, San Miguel  4469385  3D/1B  380000
#
#    superficie
# 8          49
# 11         50
# 12         50
# 16         50
# 19         44
# 25         50
# 40         56
# 41         48
# 43         49

# %% [markdown]
# ## Venta: parametros

# %%
negocio = 'venta'  # venta o arriendo
tipo = 'departamento'  # departamento, casa, oficina, sitio, parcela, etc.
comuna = 'san-miguel'
region = 'metropolitana'
estado = 'usado'  # nuevo; usado; indiferente
dorm_min = '2'  # 0 ==> 6
dorm_max = '3'  # 0 ==> 6
bano_min = '1'  # 0 ==> 6
bano_max = '1'  # 0 ==> 6
moneda = 'UFs'  # pesos; UFs
precio_min = '1.000'
precio_max = '4.000'
sup_min = '40,00'
sup_max = '60,00'
num_max_paginas = 5

# %%
# executar la query para un numero de paginas
if estado == 'nuevo': 
    condicion ="1"
elif estado == 'usado':
     condicion ="2"
else: 
    condicion ="3"
    
if moneda == 'pesos': 
    uni_mon ="1"
else: 
    uni_mon ="2" 

# print("En caso response ==> [200], todo OK!")
# print (r)
print("")

print("_____________________________________________")
print(negocio, tipo, comuna )
print("")
print ("Estado      :\t{}".format(estado))
print ("Habitaciones:\tde {} hasta {}".format(dorm_min, dorm_max))
print ("Baños       :\tde {} hasta {}".format(bano_min, bano_max))
print("Superficie m2:\tde {} hasta {}".format(sup_min, sup_max))
print("Precios en {}:\tde {} hasta {}".format(moneda, precio_min, precio_max))
print("_____________________________________________\n")

depts = []
for i in range(num_max_paginas):
    URL = "https://www.portalinmobiliario.com/" + negocio + "/" + tipo + "/" + comuna + "-" + region + "?tp=2&op=1&ca=" + condicion + "&ts=1&dd=" + dorm_min + "&dh=" + dorm_max + "&bd=" + bano_min + "&bh=" + bano_max + "&or=&mn=" + uni_mon + "&sf=1&sp=1&pd=" + precio_min + "&ph=" + precio_max + "&sd=" + sup_min + "&sh=" + sup_max+"&pg="+str(i+1)
    #print(URL)
    r = requests.get(URL)
    sleep(10)
    print(i, end="")
    res = BeautifulSoup(r.text, 'html5lib')   
    deptos = res.find_all('div', {'class':'product-item-data'})
    for d in deptos:
        dept = []
        d1 = d.find('h4').text
        dept.append(d1)
        for p in d.find_all('p'):
            d2 = p.text
            dept.append(d2)
        depts.append(dept)
dep_df = pd.DataFrame(depts)  
del dep_df[1]
dep_df.columns = ['propriedad', 'codigo', 'tipo', 'valor', 'superficie']
dep_df['valor'] = dep_df.valor.str.split(expand=True)[2]
dep_df['valor'] = dep_df.valor.str.split(',', expand=True)[0]
dep_df.valor.replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
dep_df['valor'] = pd.to_numeric(dep_df['valor'])
dep_df['codigo'] = dep_df.codigo.str.split(expand=True)[1]
dep_df['superficie'] = dep_df.superficie.str.split(expand=True)[1]
dep_df
# Out:
# _____________________________________________
# venta departamento san-miguel
#
# Estado      :	usado
# Habitaciones:	de 2 hasta 3
# Baños       :	de 1 hasta 1
# Superficie m2:	de 40,00 hasta 60,00
# Precios en UFs:	de 1.000 hasta 4.000
# _____________________________________________
#
# 01234
#                                            propriedad   codigo   tipo  valor  \
# 0   Séptima Avenida 1234 - Departamento 33, San Mi...  4466036  2D/1B   2550
# 1                 Llano Subercaseaux 3359, San Miguel  4462401  2D/1B   3436
# 2                 Avenida Santa Rosa 5741, San Miguel  3691163  3D/1B   1590
# 3   Metro Lo Ovalle / 4 Transversal / Lo Ovalle, S...  4472098  3D/1B   1685
# 4   Alcalde Pedro Alarcón  963 - Departamento 1305...  3719159  2D/1B   1748
# 5       Ciudad del Niño - San Petersburgo, San Miguel  4403972  3D/1B   1773
# 6   San Petersburgo / Tannenbaum, punto referencia...  4454465  3D/1B   1773
# 7                    San Petersburgo 6351, San Miguel  3691003  3D/1B   1800
# 8                        Santa Ester  778, San Miguel  4470380  2D/1B   1813
# 9                   Avenida Lo Ovalle 755, San Miguel  4446478  2D/1B   1816
# 10  DEPARTAMENTO EN PRIMER PISO EN PLENO DEPARTAME...  4260353  2D/1B   1833
# 11                             carnot 955, San Miguel  4482168  3D/1B   1850
# 12                 María Auxiliadora  721, San Miguel  3691138  3D/1B   1900
# 13  Depto NUEVO 3 Dormitorios Metro San Miguel, Sa...  4458796  3D/1B   1960
# 14           Primera Avenida/Panamericana, San Miguel  4386772  2D/1B   1968
# 15                Salesianos/Gran Avenida, San Miguel  4334787  2D/1B   1972
# 16  Avenida Lo Ovalle segunda transversal, San Miguel  4327411  2D/1B   2100
# 17         MARIA AUXILIADORA/GRAN AVENIDA, San Miguel  4425722  2D/1B   2100
# 18     Varas Mena 1080 - Departamento 309, San Miguel  4122402  2D/1B   2100
# 19  Metro ciudad del niño  / Gran avenida, San Miguel  4349750  3D/1B   2150
# 20  Departamento Nuevo. Maria Auxiliadora-Santa Ro...  4479346  3D/1B   2150
# 21     Alcalde Pedro Alarcón/Gran Avenida, San Miguel  4411373  2D/1B   2181
# 22                         Av. Salesianos, San Miguel  4030239  2D/1B   2189
# 23                   Chiloé / San Nicolas, San Miguel  3738284  2D/1B   2200
# 24             San Miguel/ Av. Santa Rosa, San Miguel  4438804  3D/1B   2200
# 25  PRECIO DE OPORTUNIDAD / NOVENA AVENIDA  / METR...  4309327  2D/1B   2200
# 26  Metro san Miguel, ideal INVERSIONISTAS!!!, San...  4345507  2D/1B   2231
# 27                      4ta Avenida  1175, San Miguel  4153040  2D/1B   2245
# 28                 San Nicolas/San Miguel, San Miguel  4284264  2D/1B   2250
# 29              Depto cerca Metro Lo Vial, San Miguel  4381413  2D/1B   2250
# ..                                                ...      ...    ...    ...
# 69           MARIA AUXILIADORA/SANTA ROSA, San Miguel  4374772  3D/1B   2552
# 70  MARIA AUXILIADORA/ALCALDE PEDRO ALARCON, San M...  3787627  2D/1B   2560
# 71                      octava avenida  ., San Miguel  4463213  2D/1B   2576
# 72                           Gran Avenida, San Miguel  4345526  2D/1B   2600
# 73  METRO LO VIAL / DEPARTAMENTO NUEVO CON ESTACIO...  4453017  2D/1B   2650
# 74  Gran Avenida / Av. Centenario / Espacio Urbano...  2948830  2D/1B   2670
# 75       Berlín / Desden / Av. Salecianos, San Miguel  4213066  2D/1B   2683
# 76        Cercano a metro Ciudad del Niño, San Miguel  4255281  2D/1B   2700
# 77                       Metro San Miguel, San Miguel  4198705  2D/1B   2702
# 78           CURIÑANCA / METRO SAN MIGUEL, San Miguel  4112181  3D/1B   2724
# 79                              Curiñanca, San Miguel  4355715  3D/1B   2737
# 80        Supermercado Lider Gran Avenida, San Miguel  4414963  3D/1B   2750
# 81                         Octava Avenida, San Miguel  4478282  2D/1B   2750
# 82                   Metro Ciudad el Niño, San Miguel  4247621  2D/1B   2775
# 83          Avda Salesianos / San Ignacio, San Miguel  4211956  2D/1B   2780
# 84                 Salesianos, San Miguel, San Miguel  4188294  2D/1B   2780
# 85                 Avenida Lo Ovalle 1177, San Miguel  4477013  3D/1B   2850
# 86  INVERSIONISTAS! San Miguel enrega inmedi, San ...  4477660  2D/1B   2870
# 87                   Séptima Avenida 1176, San Miguel  4358438  2D/1B   2878
# 88                Avenida Centenario 1000, San Miguel  4436364  3D/1B   2890
# 89              Alcalde Pedro Alarcón 921, San Miguel  4325068  2D/1B   2900
# 90                         METRO EL LLANO, San Miguel  4103539  2D/1B   2900
# 91           Gran Avenida / Pedro Alarcon, San Miguel  4480122  2D/1B   2900
# 92        Cuarta Avenida 1190, San Miguel, San Miguel  4476554  2D/1B   3011
# 93                          Metro Lo Vial, San Miguel  4440869  2D/1B   3100
# 94                       Curiñanca/Chiloe, San Miguel  4331642  3D/1B   3150
# 95    Curiñanaca/Chiloé/Maria Auxiliadora, San Miguel  4374747  3D/1B   3200
# 96              Curiñanca / San Francisco, San Miguel  3832326  3D/1B   3200
# 97          ALVAREZ DE TOLEDO, SAN MIGUEL, San Miguel  4108134  2D/1B   3500
# 98                    Fernando Lazcano 00, San Miguel  4318539  3D/1B   3750
#
#    superficie
# 0          58
# 1       57,50
# 2          40
# 3          48
# 4       46,47
# 5          46
# 6          46
# 7          48
# 8          46
# 9          49
# 10         60
# 11         43
# 12         49
# 13         45
# 14         57
# 15         42
# 16         60
# 17         49
# 18         47
# 19         60
# 20         48
# 21         45
# 22         45
# 23      49,50
# 24         48
# 25         44
# 26         44
# 27      42,38
# 28         47
# 29         45
# ..        ...
# 69         50
# 70         45
# 71         45
# 72         52
# 73      44,43
# 74         54
# 75         56
# 76         58
# 77         44
# 78         60
# 79         60
# 80         58
# 81         60
# 82         60
# 83      43,80
# 84      43,80
# 85         50
# 86         50
# 87         45
# 88         60
# 89         44
# 90         43
# 91         45
# 92         44
# 93         47
# 94         60
# 95         57
# 96         58
# 97         45
# 98         58
#
# [99 rows x 5 columns]

# %%
san_miguel_venta_2D = dep_df[dep_df.tipo == '2D/1B']
sumario_estat(san_miguel_venta_2D.valor)
san_miguel_venta_2D
# Out:
#  * Resumen de los datos *
#
# Propriedades:   77
# Precio Medio:  $2,448
# Precio Cntr :  $2,400
# Precio min. :  $1,748
# Precio max. :  $3,500
# Rango precios: $1,752
#                                            propriedad   codigo   tipo  valor  \
# 0   Séptima Avenida 1234 - Departamento 33, San Mi...  4466036  2D/1B   2550
# 1                 Llano Subercaseaux 3359, San Miguel  4462401  2D/1B   3436
# 4   Alcalde Pedro Alarcón  963 - Departamento 1305...  3719159  2D/1B   1748
# 8                        Santa Ester  778, San Miguel  4470380  2D/1B   1813
# 9                   Avenida Lo Ovalle 755, San Miguel  4446478  2D/1B   1816
# 10  DEPARTAMENTO EN PRIMER PISO EN PLENO DEPARTAME...  4260353  2D/1B   1833
# 14           Primera Avenida/Panamericana, San Miguel  4386772  2D/1B   1968
# 15                Salesianos/Gran Avenida, San Miguel  4334787  2D/1B   1972
# 16  Avenida Lo Ovalle segunda transversal, San Miguel  4327411  2D/1B   2100
# 17         MARIA AUXILIADORA/GRAN AVENIDA, San Miguel  4425722  2D/1B   2100
# 18     Varas Mena 1080 - Departamento 309, San Miguel  4122402  2D/1B   2100
# 21     Alcalde Pedro Alarcón/Gran Avenida, San Miguel  4411373  2D/1B   2181
# 22                         Av. Salesianos, San Miguel  4030239  2D/1B   2189
# 23                   Chiloé / San Nicolas, San Miguel  3738284  2D/1B   2200
# 25  PRECIO DE OPORTUNIDAD / NOVENA AVENIDA  / METR...  4309327  2D/1B   2200
# 26  Metro san Miguel, ideal INVERSIONISTAS!!!, San...  4345507  2D/1B   2231
# 27                      4ta Avenida  1175, San Miguel  4153040  2D/1B   2245
# 28                 San Nicolas/San Miguel, San Miguel  4284264  2D/1B   2250
# 29              Depto cerca Metro Lo Vial, San Miguel  4381413  2D/1B   2250
# 30                 San Nicolas/San Miguel, San Miguel  4399973  2D/1B   2250
# 31                    Octava Avenida 1163, San Miguel  2738267  2D/1B   2250
# 32  Gran Avenida José Miguel Carrera/Ureta C, San ...  4307989  2D/1B   2252
# 33  Dep 2D / 1B / Est.  metro Ciudad del Niño ., S...  4263056  2D/1B   2266
# 34  METRO DEPARTAMENTAL / METRO CIUDAD DEL NIÑO / ...  4453019  2D/1B   2280
# 35             PEDRO ALARCON/GRAN AVENIDA, San Miguel  4463044  2D/1B   2286
# 36  Departamento a pasos de Metro Lo Vial, San Miguel  4381412  2D/1B   2290
# 38  2 Dormitorios + Estar, Lo Ovalle, entre segund...  4450840  2D/1B   2300
# 39  Metro San Miguel - Álvarez de Toledo / C, San ...  4473190  2D/1B   2300
# 40            ENTRE 2A Y 3ERA TRANSVERSAL, San Miguel  4339115  2D/1B   2306
# 41  Sector Álvarez de Toledo/ Gran Avenida José Mi...  4240258  2D/1B   2322
# ..                                                ...      ...    ...    ...
# 59                      San Nicolas  1033, San Miguel  3789598  2D/1B   2480
# 60  Metro Ciudad del Niño/7° Avda/ 1° Transv, San ...  4080814  2D/1B   2490
# 61   Gran Avenida// Metro Ciudad del Niño, San Miguel  4466764  2D/1B   2490
# 62  INVERSIONISTAS / Metro Ciudad del Niño, San Mi...  3935844  2D/1B   2500
# 63  Metro Lo Vial, nuevo 2 Dorm, estacionamiento y...  4195701  2D/1B   2500
# 64                                 Berlin, San Miguel  4428843  2D/1B   2545
# 65                Avenida Centenario 1000, San Miguel  4409612  2D/1B   2550
# 66                  METRO CIUDAD DEL NIÑO, San Miguel  4459993  2D/1B   2550
# 67  Séptima Avenida / Metro Ciudad del Niño, San M...  4469347  2D/1B   2550
# 68                  METRO CIUDAD DEL NIÑO, San Miguel  4474584  2D/1B   2550
# 70  MARIA AUXILIADORA/ALCALDE PEDRO ALARCON, San M...  3787627  2D/1B   2560
# 71                      octava avenida  ., San Miguel  4463213  2D/1B   2576
# 72                           Gran Avenida, San Miguel  4345526  2D/1B   2600
# 73  METRO LO VIAL / DEPARTAMENTO NUEVO CON ESTACIO...  4453017  2D/1B   2650
# 74  Gran Avenida / Av. Centenario / Espacio Urbano...  2948830  2D/1B   2670
# 75       Berlín / Desden / Av. Salecianos, San Miguel  4213066  2D/1B   2683
# 76        Cercano a metro Ciudad del Niño, San Miguel  4255281  2D/1B   2700
# 77                       Metro San Miguel, San Miguel  4198705  2D/1B   2702
# 81                         Octava Avenida, San Miguel  4478282  2D/1B   2750
# 82                   Metro Ciudad el Niño, San Miguel  4247621  2D/1B   2775
# 83          Avda Salesianos / San Ignacio, San Miguel  4211956  2D/1B   2780
# 84                 Salesianos, San Miguel, San Miguel  4188294  2D/1B   2780
# 86  INVERSIONISTAS! San Miguel enrega inmedi, San ...  4477660  2D/1B   2870
# 87                   Séptima Avenida 1176, San Miguel  4358438  2D/1B   2878
# 89              Alcalde Pedro Alarcón 921, San Miguel  4325068  2D/1B   2900
# 90                         METRO EL LLANO, San Miguel  4103539  2D/1B   2900
# 91           Gran Avenida / Pedro Alarcon, San Miguel  4480122  2D/1B   2900
# 92        Cuarta Avenida 1190, San Miguel, San Miguel  4476554  2D/1B   3011
# 93                          Metro Lo Vial, San Miguel  4440869  2D/1B   3100
# 97          ALVAREZ DE TOLEDO, SAN MIGUEL, San Miguel  4108134  2D/1B   3500
#
#    superficie
# 0          58
# 1       57,50
# 4       46,47
# 8          46
# 9          49
# 10         60
# 14         57
# 15         42
# 16         60
# 17         49
# 18         47
# 21         45
# 22         45
# 23      49,50
# 25         44
# 26         44
# 27      42,38
# 28         47
# 29         45
# 30         47
# 31         58
# 32         52
# 33         58
# 34         41
# 35         40
# 36         45
# 38         54
# 39         41
# 40         41
# 41         41
# ..        ...
# 59      47,50
# 60         52
# 61         52
# 62         44
# 63         47
# 64         56
# 65         55
# 66         57
# 67         58
# 68         56
# 70         45
# 71         45
# 72         52
# 73      44,43
# 74         54
# 75         56
# 76         58
# 77         44
# 81         60
# 82         60
# 83      43,80
# 84      43,80
# 86         50
# 87         45
# 89         44
# 90         43
# 91         45
# 92         44
# 93         47
# 97         45
#
# [77 rows x 5 columns]

# %%
san_miguel_venta_3D = dep_df[dep_df.tipo == '3D/1B']
sumario_estat(san_miguel_venta_3D.valor)
san_miguel_venta_3D
# Out:
#  * Resumenventa departamento san-miguel*
#
# Propriedades:   22
# Precio Medio:  $2,406
# Precio Cntr :  $2,250
# Precio min. :  $1,590
# Precio max. :  $3,750
# Rango precios: $2,160
#                                            propriedad   codigo   tipo  valor  \
# 2                 Avenida Santa Rosa 5741, San Miguel  3691163  3D/1B   1590
# 3   Metro Lo Ovalle / 4 Transversal / Lo Ovalle, S...  4472098  3D/1B   1685
# 5       Ciudad del Niño - San Petersburgo, San Miguel  4403972  3D/1B   1773
# 6   San Petersburgo / Tannenbaum, punto referencia...  4454465  3D/1B   1773
# 7                    San Petersburgo 6351, San Miguel  3691003  3D/1B   1800
# 11                             carnot 955, San Miguel  4482168  3D/1B   1850
# 12                 María Auxiliadora  721, San Miguel  3691138  3D/1B   1900
# 13  Depto NUEVO 3 Dormitorios Metro San Miguel, Sa...  4458796  3D/1B   1960
# 19  Metro ciudad del niño  / Gran avenida, San Miguel  4349750  3D/1B   2150
# 20  Departamento Nuevo. Maria Auxiliadora-Santa Ro...  4479346  3D/1B   2150
# 24             San Miguel/ Av. Santa Rosa, San Miguel  4438804  3D/1B   2200
# 37  Lo Ovalle, entre segunda y tercera Transversal...  4406470  3D/1B   2300
# 69           MARIA AUXILIADORA/SANTA ROSA, San Miguel  4374772  3D/1B   2552
# 78           CURIÑANCA / METRO SAN MIGUEL, San Miguel  4112181  3D/1B   2724
# 79                              Curiñanca, San Miguel  4355715  3D/1B   2737
# 80        Supermercado Lider Gran Avenida, San Miguel  4414963  3D/1B   2750
# 85                 Avenida Lo Ovalle 1177, San Miguel  4477013  3D/1B   2850
# 88                Avenida Centenario 1000, San Miguel  4436364  3D/1B   2890
# 94                       Curiñanca/Chiloe, San Miguel  4331642  3D/1B   3150
# 95    Curiñanaca/Chiloé/Maria Auxiliadora, San Miguel  4374747  3D/1B   3200
# 96              Curiñanca / San Francisco, San Miguel  3832326  3D/1B   3200
# 98                    Fernando Lazcano 00, San Miguel  4318539  3D/1B   3750
#
#    superficie
# 2          40
# 3          48
# 5          46
# 6          46
# 7          48
# 11         43
# 12         49
# 13         45
# 19         60
# 20         48
# 24         48
# 37         54
# 69         50
# 78         60
# 79         60
# 80         58
# 85         50
# 88         60
# 94         60
# 95         57
# 96         58
# 98         58

# %%
writer = pd.ExcelWriter('departamentos_san_miguel.xlsx')
san_miguel_2D.to_excel(writer,'Arriendo-2D')
san_miguel_3D.to_excel(writer,'Arriendo-3D')
san_miguel_venta_2D.to_excel(writer,'Venta-2D')
san_miguel_venta_3D.to_excel(writer,'Venta-3D')
writer.save()

# %%
URL
# Out:
# 'https://www.portalinmobiliario.com/venta/departamento/san-miguel-metropolitana?tp=2&op=1&ca=2&ts=1&dd=2&dh=3&bd=1&bh=1&or=&mn=2&sf=1&sp=1&pd=1.000&ph=4.000&sd=40,00&sh=60,00&pg=5'
